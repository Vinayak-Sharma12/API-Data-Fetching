# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinayak-Sharma12/API-Data-Fetching/blob/main/Contineously_Fetching_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
import time

# WeatherAPI Key (Replace with your actual API key)
API_KEY = "7ef0cc2edc5e4ed8893101148252402"
CITY = "London"
BASE_URL = f"https://api.weatherapi.com/v1/current.json?key={API_KEY}&q={CITY}"

# API Request
while True:
  response = requests.get(BASE_URL)
# Check if request was successful
  if response.status_code == 200:
      data = response.json()
      weather = data["current"]["condition"]["text"]
      temperature = data["current"]["temp_c"]
      humidity = data["current"]["humidity"]
      wind_speed = data["current"]["wind_kph"]

      print(f"Weather in {CITY}: {weather}")
      print(f"Temperature: {temperature}°C")
      print(f"Humidity: {humidity}%")
      print(f"Wind Speed: {wind_speed} km/h")
      time.sleep(5)
  else:
      print(f"Error {response.status_code}: Unable to fetch weather data")
# Out:
# Weather in London: Moderate rain
# Temperature: 10.3°C
# Humidity: 94%
# Wind Speed: 11.9 km/h
# Weather in London: Moderate rain
# Temperature: 10.3°C
# Humidity: 94%
# Wind Speed: 11.9 km/h
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1d63a66f5e5b> in <cell line: 0>()
#      22       print(f"Humidity: {humidity}%")
#      23       print(f"Wind Speed: {wind_speed} km/h")
# ---> 24       time.sleep(5)
#      25   else:
#      26       print(f"Error {response.status_code}: Unable to fetch weather data")
#
# KeyboardInterrupt:
