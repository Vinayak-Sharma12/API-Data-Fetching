# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinayak-Sharma12/API-Data-Fetching/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
api_key='"sk-proj-ORV1HwUGs8R8vW1aRYLdAzJfhxLH9NYWyb5GDGGm9I]4JLsPWQX5L1I8A9hR_Cbs1a0JWaPCtUdqvv5LRedP2mIW18A"'

# %%
# !pip install langchain langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.5 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(api_key='"sk-proj-ORV1HwUGs8R8vW1aRYLdAzJfhxLH9NYWyb5GDGGm9I]4JLsPWQX5L1I8A9hR_Cbs1a0JWaPCtUdqvv5LRedP2mIW18A"')

# %%
llm.invoke('hello')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-7-3f0545082638> in <cell line: 0>()
# ----> 1 llm.invoke('hello')
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     367         return cast(
#     368             "ChatGeneration",
# --> 369             self.generate_prompt(
#     370                 [self._convert_input(input)],
#     371                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     944     ) -> LLMResult:
#     945         prompt_messages = [p.to_messages() for p in prompts]
# --> 946         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     947
#     948     @override
#
# ...
